# %%
from typing import List

import numpy as np

# %%
with open ('./day3_part1_input.txt', 'r') as f1:
    part1_lines = f1.readlines()

part1_rows = [line.rstrip('\n') for line in part1_lines]

# %%
part1_rows[:10]
# Out:
# ['...........#..............##...',
#  '...#....................#......',
#  '.....####...........#.#..#.#...',
#  '....##.#.......................',
#  '.......#.##......#.###.........',
#  '.#.....#.......##.......#.....#',
#  '...........##....##.#....#.....',
#  '......#.........#....#.........',
#  '..###....#.........#....#.#....',
#  '....#....#.#..#..#.........#.#.']

# %%
toboggan = np.array(part1_rows)
toboggan.shape
# Out:
# (323,)

# %%
# Where am I ? 
r = 0
c = 0

trees_hit = 0 
while r < len(part1_rows):

    if c < len(part1_rows[r]):
        print(r, c)
        print(part1_rows[r][c])
        
        if toboggan[r][c] == '#': 
            trees_hit += 1
        c += 3
        r += 1

    else:
        c = 0
# Out:
# 0 0
# .
# 1 3
# #
# 2 6
# #
# 3 9
# .
# 4 12
# .
# 5 15
# #
# 6 18
# #
# 7 21
# #
# 8 24
# #
# 9 27
# #
# 10 30
# #
# 11 0
# .
# 12 3
# .
# 13 6
# .
# 14 9
# .
# 15 12
# .
# 16 15
# .
# 17 18
# #
# 18 21
# #
# 19 24
# .
# 20 27
# .
# 21 30
# .
# 22 0
# #
# 23 3
# .
# 24 6
# .
# 25 9
# .
# 26 12
# #
# 27 15
# .
# 28 18
# .
# 29 21
# .
# 30 24
# .
# 31 27
# .
# 32 30
# #
# 33 0
# .
# 34 3
# #
# 35 6
# .
# 36 9
# .
# 37 12
# .
# 38 15
# .
# 39 18
# #
# 40 21
# .
# 41 24
# .
# 42 27
# #
# 43 30
# .
# 44 0
# .
# 45 3
# .
# 46 6
# .
# 47 9
# #
# 48 12
# #
# 49 15
# .
# 50 18
# .
# 51 21
# .
# 52 24
# .
# 53 27
# .
# 54 30
# .
# 55 0
# .
# 56 3
# .
# 57 6
# .
# 58 9
# .
# 59 12
# .
# 60 15
# #
# 61 18
# .
# 62 21
# #
# 63 24
# .
# 64 27
# .
# 65 30
# .
# 66 0
# #
# 67 3
# .
# 68 6
# #
# 69 9
# .
# 70 12
# .
# 71 15
# .
# 72 18
# #
# 73 21
# .
# 74 24
# .
# 75 27
# .
# 76 30
# .
# 77 0
# .
# 78 3
# .
# 79 6
# .
# 80 9
# .
# 81 12
# #
# 82 15
# .
# 83 18
# .
# 84 21
# .
# 85 24
# .
# 86 27
# ...

# %%
trees_hit
# Out:
# 58

# %%
toboggan[:5]
# Out:
# array(['...........#..............##...',
#        '...#....................#......',
#        '.....####...........#.#..#.#...',
#        '....##.#.......................',
#        '.......#.##......#.###.........'], dtype='<U31')

# %%
marked_path.reshape(-1, 1).shape
# Out:
# (323, 1)
